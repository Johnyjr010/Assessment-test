# %% [markdown]
# import panda

# %%
import pandas as pd

# %% [markdown]
# read csv files

# %%
df = pd.read_csv("Salaries.csv")

# %% [markdown]
# printing first 5 lines

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# print last 5 lines

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
print(df["salary"])
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %% [markdown]
# check a particular column type

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# check types for all the columns

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %% [markdown]
# find mean of salary

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %% [markdown]
# find mean of salary of particular grp

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df.groupby('sex')[['salary']].mean()
# Out:
#                salary
# sex
# Female  101002.410256
# Male    115045.153846

# %%
df_sub=df[df['salary']>120000]
print(df_sub)
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df[['rank','salary']]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
df[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %%
df_sub.loc[10:20,['rank','sex','salary']]
# Out:
#     rank   sex  salary
# 10  Prof  Male  128250
# 11  Prof  Male  134778
# 13  Prof  Male  162200
# 14  Prof  Male  153750
# 15  Prof  Male  150480
# 19  Prof  Male  150500

# %%
df_sub.shape
# Out:
# (25, 6)

# %%
df_sub.iloc[10:20,[0,2,3,4,5]]
# Out:
#     rank  phd  service     sex  salary
# 26  Prof   38       19    Male  148750
# 27  Prof   45       43    Male  155865
# 29  Prof   21       20    Male  123683
# 31  Prof   22       21    Male  155750
# 35  Prof   28       23    Male  126933
# 36  Prof   45       45    Male  146856
# 39  Prof   18       18  Female  129000
# 40  Prof   39       36  Female  137000
# 44  Prof   23       19  Female  151768
# 45  Prof   25       25  Female  140096

# %%
df.iloc[:,0]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df[0:7]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df_sorted=df.sort_values(by='service')
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %% [markdown]
# service "kuranjavarum" salary "kudiyavarum"

# %%
df_sorted=df.sort_values(by=['salary','service'],ascending=[True,False])
df_sorted.head()
df_sorted[:10]
# Out:
#          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 57   AsstProf          A    3        1  Female   72500
# 55   AsstProf          A    2        0  Female   72500
# 22   AsstProf          A    4        2    Male   73000
# 64  AssocProf          A   26       24  Female   73300
# 53   AsstProf          A    5        3  Female   73500
# 46   AsstProf          B   11        3  Female   74692

# %% [markdown]
# HOTEL BOOKINGS

# %%
df_hotel = pd.read_csv('hotel_bookings.csv')

# %%
df_hotel.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df_hotel['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
df_hotel['meal']
# Out:
# 0         BB
# 1         BB
# 2         BB
# 3         BB
# 4         BB
#           ..
# 119385    BB
# 119386    BB
# 119387    BB
# 119388    BB
# 119389    HB
# Name: meal, Length: 119390, dtype: object

# %%
df_hotel['agent'].mean()
# Out:
# 86.69338185346919

# %%
df_hotel.groupby('agent')[['adults']].mean()
# Out:
#          adults
# agent
# 1.0    1.901961
# 2.0    1.907407
# 3.0    1.885479
# 4.0    1.872340
# 5.0    1.854545
# ...         ...
# 510.0  1.000000
# 526.0  2.000000
# 527.0  1.714286
# 531.0  1.985294
# 535.0  1.000000
#
# [333 rows x 1 columns]

# %%
df_hotel_sorted=df_hotel.sort_values(by='agent')
df_hotel_sorted.head()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 74065  City Hotel            1        314               2015
# 42883  City Hotel            0        168               2015
# 42884  City Hotel            0        168               2015
# 42885  City Hotel            1        168               2015
# 42887  City Hotel            0        168               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 74065             August                        35                         27
# 42883          September                        37                         11
# 42884          September                        37                         11
# 42885          September                        37                         11
# 42887          September                        37                         11
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df_hotel[10:20]
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 10  Resort Hotel            1         23               2015
# 11  Resort Hotel            0         35               2015
# 12  Resort Hotel            0         68               2015
# 13  Resort Hotel            0         18               2015
# 14  Resort Hotel            0         37               2015
# 15  Resort Hotel            0         68               2015
# 16  Resort Hotel            0         37               2015
# 17  Resort Hotel            0         12               2015
# 18  Resort Hotel            0          0               2015
# 19  Resort Hotel            0          7               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 10               July                        27                          1
# 11               July                        27                          1
# 12               July                        27                          1
# ...

# %%
df_hotel_sorted=df_hotel.sort_values(by=['agent','adults'],ascending=[True,False])
df_hotel_sorted.head()
df_hotel_sorted[:10]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40211  City Hotel            0         18               2015
# 40222  City Hotel            0         18               2015
# 40227  City Hotel            0         18               2015
# 40274  City Hotel            0         12               2015
# 40299  City Hotel            0         20               2015
# 40312  City Hotel            0         20               2015
# 40330  City Hotel            0         20               2015
# 40373  City Hotel            0        132               2015
# 40436  City Hotel            0         16               2015
# 40484  City Hotel            0         25               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40211               July                        29                         18
# 40222               July                        29                         18
# ...
